# %%
Huggy does not see his environment, we provides him some necessary information

# %% [markdown]
# Huggy does not see his environment, we provides him some necessary information.
# 1. The target (stick) position.
# 2. The relative position between himself and the target
# 3. The orientation of his legs.
#
#
# One of the foundations of the deep rl is REWARD HYPOTHESIS: a goal can be described as maximization of expected commulated reward.
#
# 1. Oreintation Bonus
# 2. Time penulty
# 3. Rotation Penulty
# 4. Getting to the target reward.

# %%
# !git clone --depth 1 https://github.com/Unity-TEchnologies/ml-agents
# Out:
# Cloning into 'ml-agents'...
# remote: Enumerating objects: 2347, done.
# remote: Counting objects: 100% (2347/2347), done.
# remote: Compressing objects: 100% (1882/1882), done.
# remote: Total 2347 (delta 889), reused 1327 (delta 447), pack-reused 0
# Receiving objects: 100% (2347/2347), 97.18 MiB | 15.02 MiB/s, done.
# Resolving deltas: 100% (889/889), done.
# Updating files: 100% (2177/2177), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# %cd ml-agents
# !pip install -e ./ml-agents-envs
# !pip install -e ./ml-agents

# %%
# !mkdir ./trained-envs-executables
# !mkdir ./trained-envs-executables/linux

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF" -O ./trained-envs-executables/linux/Huggy.zip && rm -rf /tmp/cookies.txt
# Out:
# --2023-10-16 17:46:16--  https://docs.google.com/uc?export=download&confirm=t&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF
# Resolving docs.google.com (docs.google.com)... 64.233.170.101, 64.233.170.139, 64.233.170.138, ...
# Connecting to docs.google.com (docs.google.com)|64.233.170.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0k-28-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/hhkt09m3lkel2k48sbovuoj08mksu9hs/1697478375000/15803371278684422230/*/1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF?e=download&uuid=934868c2-88db-4ac1-a38c-5b54151e0bc7 [following]
# ...
# --2023-10-16 17:46:16--  https://doc-0k-28-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/hhkt09m3lkel2k48sbovuoj08mksu9hs/1697478375000/15803371278684422230/*/1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF?e=download&uuid=934868c2-88db-4ac1-a38c-5b54151e0bc7
# ...

# %%
# %%capture
# !unzip -d ./trained-envs-executables/linux/ ./trained-envs-executables/linux/Huggy.zip

# %%
# !chmod -R 755 ./trained-envs-executables/linux/Huggy

# %% [markdown]
# Creating the Huggy config file

# %%
# !mlagents-learn /content/ml-agents/config/ppo/Huggy.yaml --env=/content/ml-agents/trained-envs-executables/linux/Huggy/Huggy --run-id="Huggy" --no-graphics
# Out:
# 2023-10-16 17:49:05.756872: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
# ...

# %%
# !pip install huggingface_hub

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# !mlagents-push-to-hf --run-id="HuggyTraining" --local-dir="./results/Huggy" --repo-id="irishwerr/ppo-Huggy" --commit-message="Huggy"
# Out:
# [INFO] This function will create a model card and upload your HuggyTraining into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo HuggyTraining to the Hugging Face Hub
# Huggy-19777.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
# Huggy-19777.pt:   0% 0.00/4.51M [00:00<?, ?B/s]
#
# Huggy-39824.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
# Huggy-39824.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
#
# Upload 9 LFS files:   0% 0/9 [00:00<?, ?it/s]
#
#
#
#
# Huggy.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
#
#
# Huggy.onnx:   1% 16.4k/2.27M [00:01<02:58, 12.7kB/s]
#
#
# Huggy-19777.onnx:   1% 16.4k/2.27M [00:01<03:02, 12.4kB/s]
#
# Huggy-39824.onnx:   1% 16.4k/2.27M [00:01<03:01, 12.4kB/s]
# Huggy-19777.pt:   0% 16.4k/4.51M [00:01<06:03, 12.4kB/s]
#
#
#
#
# Huggy.onnx:   4% 98.3k/2.27M [00:01<00:26, 83.3kB/s]
#
#
# Huggy-19777.onnx:   4% 98.3k/2.27M [00:01<00:26, 81.6kB/s]
# Huggy-19777.pt:   3% 131k/4.51M [00:01<00:39, 110kB/s]
#
# ...
